# %%
import pandas as pd
import os
from pathlib import Path

# %% [markdown]
# # ExcelDataProcessor Class Documentation
#
# ## Overview
# The `ExcelDataProcessor` class is designed to process Excel files containing data with Persian calendar dates. It provides functionality to read multiple Excel files, extract specific cell values, and organize the data into a sorted DataFrame based on Persian calendar dates.
#
# ## Key Features
# - Reads both regular Excel files (.xls, .xlsx) and HTML-formatted Excel files
# - Handles Persian calendar dates in column names
# - Converts string values to float type
# - Supports tuple-based column names (common in multi-index Excel files)
# - Sorts data based on Persian calendar dates
#
# ## Class Methods
#
# ### `__init__(data_directory='data')`
# Initializes the processor with a specified data directory.
# - **Parameters:**
#   - `data_directory` (str): Path to the directory containing Excel files (default: 'data')
#
# ### `read_excel_files()`
# Reads all Excel files from the specified directory.
# - **Returns:**
#   - `bool`: True if files were successfully read, False otherwise
#
# ### `get_cell_values(row_idx, col_idx)`
# Extracts values from specific row and column indices across all files.
# - **Parameters:**
#   - `row_idx` (int): Row index
#   - `col_idx` (int): Column index
# - **Returns:**
#   - `pd.DataFrame`: DataFrame with columns:
#     - Filename: Name of the Excel file
#     - Value: Numeric value from the specified cell
#     - Date: Formatted Persian date
#     - Column_Detail: Second part of tuple column name (if available)
#
# ## Usage Example
# ```python
# # Create an instance
# processor = ExcelDataProcessor(data_directory='data')
#
# # Read all Excel files
# if processor.read_excel_files():
#     # Get values from row 1, column 13
#     result_df = processor.get_cell_values(1, 13)
#     print(result_df)
# ```
#
# ## Data Format
# The resulting DataFrame will be sorted by Persian calendar dates and include:
# - Files with valid dates sorted in chronological order
# - Files with unknown dates placed at the end
# - All numeric values converted to float type
# - Additional column details when available

# %%
class ExcelDataProcessor:
    def __init__(self, data_directory='data'):
        """
        Initialize ExcelDataProcessor with a data directory path.
        
        Args:
            data_directory (str): Path to the directory containing Excel files
        """
        self.data_directory = data_directory
        self.excel_data = {}
        self._base_path = Path(os.getcwd()).parent if os.path.basename(os.getcwd()) == 'estimator' else Path(os.getcwd())
        self._data_path = self._base_path / data_directory
        
    def read_excel_files(self):
        """
        Read all Excel files in the specified directory.
        Returns:
            bool: True if files were read successfully, False otherwise
        """
        try:
            # Iterate through all files in the directory
            for file_path in self._data_path.glob('*.xls*'):
                try:
                    try:
                        # First try to read as a regular Excel file
                        df = pd.read_excel(
                            file_path,
                            engine='openpyxl' if file_path.suffix == '.xlsx' else 'xlrd'
                        )
                    except Exception as excel_error:
                        # If that fails, try to read as HTML
                        print(f"Attempting to read {file_path.name} as HTML...")
                        df = pd.read_html(
                            file_path,
                            encoding='utf-8',
                            flavor='lxml'
                        )[0]
                    
                    if not df.empty:
                        self.excel_data[file_path.name] = df
                        print(f"Successfully read {file_path.name}")
                    else:
                        print(f"Warning: {file_path.name} is empty")
                        
                except Exception as e:
                    print(f"Error reading {file_path.name}: {str(e)}")
            
            return len(self.excel_data) > 0
            
        except Exception as e:
            print(f"Error accessing directory: {str(e)}")
            return False
    
    def get_cell_values(self, row_idx, col_idx):
        """
        Get values from specific row and column indices across all files.
        
        Args:
            row_idx (int): Row index
            col_idx (int): Column index
            
        Returns:
            pd.DataFrame: DataFrame with filename, value, date information, and column details
        """
        values = []
        dates = []
        filenames = []
        column_names = []  # For the second part of the tuple
        
        for filename, df in self.excel_data.items():
            try:
                # Get value and convert to float
                value = df.iloc[row_idx, col_idx]
                if isinstance(value, str):
                    value = ''.join(c for c in value if c.isdigit() or c == '.')
                    value = float(value) if value else 0.0
                else:
                    value = float(value) if pd.notna(value) else 0.0
                
                # Extract date from column name (first part of tuple)
                col_name = df.columns[col_idx]
                if isinstance(col_name, tuple):
                    date_part = col_name[0]  # First part for date
                    col_detail = col_name[1]  # Second part for additional info
                else:
                    date_part = col_name
                    col_detail = "Unknown"
                
                formatted_date = self._extract_persian_date(date_part)
                
                filenames.append(filename)
                values.append(value)
                dates.append(formatted_date)
                column_names.append(col_detail)
                
            except (IndexError, ValueError) as e:
                print(f"Error processing {filename}: {str(e)}")
                continue
        
        return self._create_sorted_dataframe(filenames, values, dates, column_names)
    
    def _extract_persian_date(self, col_name):
        """
        Extract and format Persian date from column name.
        
        Args:
            col_name (str): Column name containing date
            
        Returns:
            str: Formatted date or 'Unknown'
        """
        try:
            import re
            date_match = re.search(r'\d{2,4}[/\-]\d{1,2}[/\-]\d{1,2}', str(col_name))
            if date_match:
                date = date_match.group()
                parts = date.split('/')
                if len(parts[0]) == 2:
                    parts[0] = '14' + parts[0] if int(parts[0]) < 50 else '13' + parts[0]
                return f"{parts[0]}/{parts[1].zfill(2)}/{parts[2].zfill(2)}"
        except Exception:
            pass
        return "Unknown"
    
    def _create_sorted_dataframe(self, filenames, values, dates, column_names):
        """
        Create and sort DataFrame by Persian calendar dates.
        
        Args:
            filenames (list): List of filenames
            values (list): List of values
            dates (list): List of dates
            column_names (list): List of column second parts
            
        Returns:
            pd.DataFrame: Sorted DataFrame
        """
        df = pd.DataFrame({
            'Filename': filenames,
            'Value': values,
            'Date': dates,
            'Column_Detail': column_names
        })
        
        # Create sorting key
        df['SortKey'] = df['Date'].apply(lambda x: float('inf') if x == 'Unknown' 
                                        else int(''.join(x.split('/'))))
        
        # Sort and clean up
        df_sorted = df.sort_values(by='SortKey', ascending=True)
        df_sorted = df_sorted.drop('SortKey', axis=1)
        return df_sorted.reset_index(drop=True)

# %% [markdown]
# ### Example --- read file data

# %%
# Create an instance of ExcelDataProcessor
processor = ExcelDataProcessor(data_directory='data')

# Read all Excel files
if processor.read_excel_files():
    # Get values from row 1, column 13 (same as before)
    result_df = processor.get_cell_values(1, 13)
# Out:
# Attempting to read 0013efe6-cd1a-4023-8a47-152850eebefc.xls as HTML...
# Successfully read 0013efe6-cd1a-4023-8a47-152850eebefc.xls
# Attempting to read 00b9b5c8-00ac-44b1-a9ae-8156ab5f63dd.xls as HTML...
# Successfully read 00b9b5c8-00ac-44b1-a9ae-8156ab5f63dd.xls
# Attempting to read 0558e64e-5345-4c65-8fc0-991770603431.xls as HTML...
# Successfully read 0558e64e-5345-4c65-8fc0-991770603431.xls
# Attempting to read 057ff4ea-d363-41e7-9ffa-34b48ed1246e.xls as HTML...
# Successfully read 057ff4ea-d363-41e7-9ffa-34b48ed1246e.xls
# Attempting to read 08a39594-ad71-40dd-b8cc-cc691083516d.xls as HTML...
# Successfully read 08a39594-ad71-40dd-b8cc-cc691083516d.xls
# Attempting to read 12264d38-3f6e-471f-9d57-051f0009aae9.xls as HTML...
# Successfully read 12264d38-3f6e-471f-9d57-051f0009aae9.xls
# Attempting to read 1b04c298-6fbe-4ba3-b466-62f317e16065.xls as HTML...
# Successfully read 1b04c298-6fbe-4ba3-b466-62f317e16065.xls
# Attempting to read 1c2258b8-9b36-45f2-813f-3567e928123a.xls as HTML...
# Successfully read 1c2258b8-9b36-45f2-813f-3567e928123a.xls
# Attempting to read 1fa3b264-e21f-421d-9ea8-2a35fc02d314.xls as HTML...
# Error reading 1fa3b264-e21f-421d-9ea8-2a35fc02d314.xls: list index out of range
# Attempting to read 2173f383-cc45-4a0e-8184-0282c10127af.xls as HTML...
# Successfully read 2173f383-cc45-4a0e-8184-0282c10127af.xls
# Attempting to read 328c5b8d-796a-473e-80d5-8107525447f5.xls as HTML...
# Successfully read 328c5b8d-796a-473e-80d5-8107525447f5.xls
# Attempting to read 3359ada2-a2ef-4c09-9610-369e96e6f318.xls as HTML...
# Error reading 3359ada2-a2ef-4c09-9610-369e96e6f318.xls: list index out of range
# Attempting to read 33712f03-28ca-4140-b836-00da55faa92c.xls as HTML...
# Successfully read 33712f03-28ca-4140-b836-00da55faa92c.xls
# Attempting to read 41a08ff6-6e02-4f81-971f-2d5ec3480aec.xls as HTML...
# Successfully read 41a08ff6-6e02-4f81-971f-2d5ec3480aec.xls
# Attempting to read 50421afd-9090-442f-9f8c-5baa8603b484.xls as HTML...
# Successfully read 50421afd-9090-442f-9f8c-5baa8603b484.xls
# Attempting to read 53099b24-26ab-4c6c-9f93-d970ae1a521c.xls as HTML...
# Successfully read 53099b24-26ab-4c6c-9f93-d970ae1a521c.xls
# Attempting to read 54edbeba-1091-4d31-922e-4d8d61c7cb00.xls as HTML...
# Successfully read 54edbeba-1091-4d31-922e-4d8d61c7cb00.xls
# Attempting to read 5624b460-85f3-43c6-b16a-1cadc3ab230f.xls as HTML...
# Successfully read 5624b460-85f3-43c6-b16a-1cadc3ab230f.xls
# Attempting to read 597301a9-e86c-4b1a-b124-f4f33ec9c983.xls as HTML...
# Successfully read 597301a9-e86c-4b1a-b124-f4f33ec9c983.xls
# Attempting to read 5b9aee80-8884-4435-a33d-218a09c51535.xls as HTML...
# Error reading 5b9aee80-8884-4435-a33d-218a09c51535.xls: list index out of range
# Attempting to read 608040a8-950f-4146-995b-335800884fe5.xls as HTML...
# Successfully read 608040a8-950f-4146-995b-335800884fe5.xls
# Attempting to read 63ab0a93-bb4e-4d47-8453-e20b131b2919.xls as HTML...
# Error reading 63ab0a93-bb4e-4d47-8453-e20b131b2919.xls: No tables found matching regex '.+'
# Attempting to read 65d695f4-8f1f-45bc-bfe5-1b875371379a.xls as HTML...
# Successfully read 65d695f4-8f1f-45bc-bfe5-1b875371379a.xls
# Attempting to read 69066e35-9bed-4c0f-aa65-98de64ab4869.xls as HTML...
# Successfully read 69066e35-9bed-4c0f-aa65-98de64ab4869.xls
# Attempting to read 6910b37d-4f58-4d1f-bbd2-b2c91b62072a.xls as HTML...
# Successfully read 6910b37d-4f58-4d1f-bbd2-b2c91b62072a.xls
# Attempting to read 76eb5d39-e81b-4cc1-b4fe-4c4a667e7a98.xls as HTML...
# Successfully read 76eb5d39-e81b-4cc1-b4fe-4c4a667e7a98.xls
# Attempting to read 7a01128b-2a9b-4d2e-8209-ffd0bd23ceb8.xls as HTML...
# Successfully read 7a01128b-2a9b-4d2e-8209-ffd0bd23ceb8.xls
# Attempting to read 80b32a0e-f4ef-4a0b-9ace-c037aa509851.xls as HTML...
# Successfully read 80b32a0e-f4ef-4a0b-9ace-c037aa509851.xls
# Attempting to read 81a6ddff-1ecc-42c0-be4a-d2657add43f4.xls as HTML...
# Error reading 81a6ddff-1ecc-42c0-be4a-d2657add43f4.xls: No tables found matching regex '.+'
# Attempting to read 8b1da9df-09d4-41f8-9cd3-7303d23beab4.xls as HTML...
# Successfully read 8b1da9df-09d4-41f8-9cd3-7303d23beab4.xls
# Attempting to read 8cac28c5-3e6e-4bce-9b4b-c0b0a4784d29.xls as HTML...
# Successfully read 8cac28c5-3e6e-4bce-9b4b-c0b0a4784d29.xls
# Attempting to read 8d62a8ce-c9a4-44e1-8f4c-4c833cf1f8a9.xls as HTML...
# Successfully read 8d62a8ce-c9a4-44e1-8f4c-4c833cf1f8a9.xls
# Attempting to read 92f6977d-cda6-4904-8615-f678bc36688c.xls as HTML...
# Successfully read 92f6977d-cda6-4904-8615-f678bc36688c.xls
# Attempting to read 95f34078-32a7-45af-b8fb-88f159a9a6e3.xls as HTML...
# Successfully read 95f34078-32a7-45af-b8fb-88f159a9a6e3.xls
# Attempting to read 9b83b316-8caf-4ee3-8cdd-8d542ce522db.xls as HTML...
# Successfully read 9b83b316-8caf-4ee3-8cdd-8d542ce522db.xls
# Attempting to read 9d8f90ea-2cd3-47a9-ac8e-29b3fc4719b7.xls as HTML...
# Successfully read 9d8f90ea-2cd3-47a9-ac8e-29b3fc4719b7.xls
# Attempting to read 9f0e15ef-1f2f-483c-aa42-af54a906a729.xls as HTML...
# Successfully read 9f0e15ef-1f2f-483c-aa42-af54a906a729.xls
# Attempting to read a2d0a6f6-6408-4e37-9f07-5e59cb15d965.xls as HTML...
# Successfully read a2d0a6f6-6408-4e37-9f07-5e59cb15d965.xls
# Attempting to read a605c3e9-a182-49e5-9c81-b5f34fb16a44.xls as HTML...
# Successfully read a605c3e9-a182-49e5-9c81-b5f34fb16a44.xls
# Attempting to read a7ee605d-2395-4980-b3b3-bbe3cbf0578f.xls as HTML...
# Successfully read a7ee605d-2395-4980-b3b3-bbe3cbf0578f.xls
# Attempting to read aaee6fa8-ef91-44d0-a492-3f61f5b8c5ac.xls as HTML...
# Successfully read aaee6fa8-ef91-44d0-a492-3f61f5b8c5ac.xls
# Attempting to read bbd61b58-8e82-4185-a89d-a81b18ae3095.xls as HTML...
# Successfully read bbd61b58-8e82-4185-a89d-a81b18ae3095.xls
# Attempting to read bf9ffaa4-5a90-426a-ab78-4bd393427e03.xls as HTML...
# Successfully read bf9ffaa4-5a90-426a-ab78-4bd393427e03.xls
# Attempting to read c1fe2967-6a45-4469-b203-cd289100bd57.xls as HTML...
# Successfully read c1fe2967-6a45-4469-b203-cd289100bd57.xls
# Attempting to read c3b89a68-0e30-48ca-8b81-f902ee2d121d.xls as HTML...
# Successfully read c3b89a68-0e30-48ca-8b81-f902ee2d121d.xls
# Attempting to read c6b0a86a-2e86-4626-8135-727803762fc1.xls as HTML...
# Successfully read c6b0a86a-2e86-4626-8135-727803762fc1.xls
# Attempting to read ce82d8fb-65b2-42e2-aec3-7b37fceff7a2.xls as HTML...
# Successfully read ce82d8fb-65b2-42e2-aec3-7b37fceff7a2.xls
# Attempting to read d3170f33-8233-4c34-865e-08bc891382b9.xls as HTML...
# Successfully read d3170f33-8233-4c34-865e-08bc891382b9.xls
# Attempting to read dbea75ec-75f6-4bba-b606-0dfae49e19a2.xls as HTML...
# Successfully read dbea75ec-75f6-4bba-b606-0dfae49e19a2.xls
# Attempting to read df6c27d3-ca97-4b79-9825-a15142fa34cc.xls as HTML...
# Error reading df6c27d3-ca97-4b79-9825-a15142fa34cc.xls: list index out of range
# Attempting to read e0789c92-4c7d-4f25-a864-11091c892ddc.xls as HTML...
# Successfully read e0789c92-4c7d-4f25-a864-11091c892ddc.xls
# Attempting to read e0f4e4e4-e7f4-4caa-ab88-a7d5010f1e76.xls as HTML...
# Successfully read e0f4e4e4-e7f4-4caa-ab88-a7d5010f1e76.xls
# Attempting to read e48085cc-9f12-4ea1-9334-371ae86a1a88.xls as HTML...
# Successfully read e48085cc-9f12-4ea1-9334-371ae86a1a88.xls
# Attempting to read e6e6c8fd-97f1-4f20-af54-013ac69a986e.xls as HTML...
# Successfully read e6e6c8fd-97f1-4f20-af54-013ac69a986e.xls
# Attempting to read ed7c8d14-ff4b-4307-b3fe-a7f66839499e.xls as HTML...
# Successfully read ed7c8d14-ff4b-4307-b3fe-a7f66839499e.xls
# Attempting to read eda9e168-c631-4f82-a843-d253ff3a9533.xls as HTML...
# Successfully read eda9e168-c631-4f82-a843-d253ff3a9533.xls
# Attempting to read f44aba8e-ab05-456e-a048-65b0002cbda3.xls as HTML...
# Successfully read f44aba8e-ab05-456e-a048-65b0002cbda3.xls
# Attempting to read f70089aa-d3a3-4761-bf9d-958c5c3f1c89.xls as HTML...
# Successfully read f70089aa-d3a3-4761-bf9d-958c5c3f1c89.xls
# Attempting to read fc13cbda-68f0-4911-bcda-66cf5e7fe57f.xls as HTML...
# Successfully read fc13cbda-68f0-4911-bcda-66cf5e7fe57f.xls

# %%
result_df.to_csv('output.csv', index=False)
result_df
